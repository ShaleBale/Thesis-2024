# %%
import pandas as pd

# %%
conda install matplotlib
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\shlbs\miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       haa95532_0         123 KB
#     certifi-2023.7.22          |  py310haa95532_0         154 KB
#     contourpy-1.0.5            |  py310h59b6b97_0         159 KB
#     intel-openmp-2023.1.0      |   h59b6b97_46319         2.7 MB
#     kiwisolver-1.4.4           |  py310hd77b12b_0          60 KB
#     matplotlib-3.7.2           |  py310haa95532_0           9 KB
#     matplotlib-base-3.7.2      |  py310h4ed8f06_0         6.6 MB
#     mkl-2023.1.0               |   h6b88ed4_46357       155.6 MB
#     mkl-service-2.4.0          |  py310h2bbff1b_1          44 KB
#     mkl_fft-1.3.8              |  py310h2bbff1b_0         170 KB
#     mkl_random-1.2.4           |  py310h59b6b97_0         227 KB
#     numpy-1.26.0               |  py310h055cbcc_0          10 KB
#     numpy-base-1.26.0          |  py310h65a83cf_0         6.1 MB
#     openssl-1.1.1w             |       h2bbff1b_0         5.5 MB
#     pillow-9.4.0               |  py310hd77b12b_0        1007 KB
#     pyparsing-3.0.9            |  py310haa95532_0         154 KB
#     tbb-2021.8.0               |       h59b6b97_0         149 KB
#     ------------------------------------------------------------
#                                            Total:       178.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   brotli             pkgs/main/win-64::brotli-1.0.9-h2bbff1b_7
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_7
#   contourpy          pkgs/main/win-64::contourpy-1.0.5-py310h59b6b97_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   freetype           pkgs/main/win-64::freetype-2.12.1-ha860e81_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2023.1.0-h59b6b97_46319
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py310hd77b12b_0
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_7
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_7
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_7
#   matplotlib         pkgs/main/win-64::matplotlib-3.7.2-py310haa95532_0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.7.2-py310h4ed8f06_0
#   mkl                pkgs/main/win-64::mkl-2023.1.0-h6b88ed4_46357
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py310h2bbff1b_1
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.8-py310h2bbff1b_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.4-py310h59b6b97_0
#   munkres            pkgs/main/noarch::munkres-1.1.4-py_0
#   numpy              pkgs/main/win-64::numpy-1.26.0-py310h055cbcc_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.26.0-py310h65a83cf_0
#   pillow             pkgs/main/win-64::pillow-9.4.0-py310hd77b12b_0
#   pyparsing          pkgs/main/win-64::pyparsing-3.0.9-py310haa95532_0
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-haa95532_0 --> 2023.08.22-haa95532_0
#   certifi                         2022.12.7-py310haa95532_0 --> 2023.7.22-py310haa95532_0
#   openssl                                 1.1.1t-h2bbff1b_0 --> 1.1.1w-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# pillow-9.4.0         | 1007 KB   |            |   0%
#
# mkl_fft-1.3.8        | 170 KB    |            |   0%
#
#
# matplotlib-base-3.7. | 6.6 MB    |            |   0%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    |            |   0%
#
#
#
#
# numpy-1.26.0         | 10 KB     |            |   0%
#
#
#
#
#
# kiwisolver-1.4.4     | 60 KB     |            |   0%
#
#
#
#
#
#
# tbb-2021.8.0         | 149 KB    |            |   0%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    |            |   0%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
# matplotlib-3.7.2     | 9 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 123 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.4     | 227 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.0.5      | 159 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 154 KB    |            |   0%
# pillow-9.4.0         | 1007 KB   | 6          |   6%
#
#
# matplotlib-base-3.7. | 6.6 MB    | 2          |   2%
#
# mkl_fft-1.3.8        | 170 KB    | #######5   |  75%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    |            |   0%
#
#
#
#
# numpy-1.26.0         | 10 KB     | ########## | 100%
#
#
#
#
#
# kiwisolver-1.4.4     | 60 KB     | ##6        |  27%
#
#
#
#
#
#
# tbb-2021.8.0         | 149 KB    | #          |  11%
#
#
# matplotlib-base-3.7. | 6.6 MB    | 8          |   9%
# pillow-9.4.0         | 1007 KB   | ####9      |  49%
#
#
#
#
# numpy-1.26.0         | 10 KB     | ########## | 100%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | 3          |   4%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    |            |   1%
#
# mkl_fft-1.3.8        | 170 KB    | ########## | 100%
#
#
#
#
#
# kiwisolver-1.4.4     | 60 KB     | ########## | 100%
#
#
#
#
#
#
# tbb-2021.8.0         | 149 KB    | ########## | 100%
#
#
#
#
#
# kiwisolver-1.4.4     | 60 KB     | ########## | 100%
#
#
#
#
#
#
# tbb-2021.8.0         | 149 KB    | ########## | 100%
# pillow-9.4.0         | 1007 KB   | #########6 |  97%
#
#
# matplotlib-base-3.7. | 6.6 MB    | #5         |  15%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   0%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | 7          |   8%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #4         |  14%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ##1        |  22%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   0%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ##         |  20%
#
#
#
#
#
#
#
#
#
# matplotlib-3.7.2     | 9 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# matplotlib-3.7.2     | 9 KB      | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   0%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ##9        |  29%
# pillow-9.4.0         | 1007 KB   | ########## | 100%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ##4        |  24%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ###8       |  39%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   0%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #2         |  12%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | 7          |   8%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ##7        |  27%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #####      |  51%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   1%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #5         |  16%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #5         |  16%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ######1    |  62%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  |            |   1%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ###8       |  39%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ##4        |  24%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #8         |  19%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ###        |  31%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ####3      |  43%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ##1        |  22%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ####       |  40%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ####8      |  49%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ##4        |  25%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | #########9 |  99%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #####      |  50%
#
#
# matplotlib-base-3.7. | 6.6 MB    | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 123 KB    | #2         |  13%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ##7        |  28%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.4     | 227 KB    | 7          |   7%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 123 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2023 | 123 KB    | ########## | 100%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ###1       |  31%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 1          |   2%
#
#
#
#
#
#
#
# intel-openmp-2023.1. | 2.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ######8    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.0.5      | 159 KB    | #          |  10%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.4     | 227 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.4     | 227 KB    | ########## | 100%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ###4       |  34%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     | ###6       |  36%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ###7       |  37%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 2          |   2%
#
#
# matplotlib-base-3.7. | 6.6 MB    | #######    |  71%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | #          |  10%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | #########1 |  92%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ####1      |  41%
#
#
# matplotlib-base-3.7. | 6.6 MB    | #######8   |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 154 KB    | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.0.5      | 159 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.0.5      | 159 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 2          |   3%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ####3      |  44%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 3          |   3%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ####8      |  48%
#
#
# matplotlib-base-3.7. | 6.6 MB    | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 154 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.0.9      | 154 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 3          |   3%
#
#
# matplotlib-base-3.7. | 6.6 MB    | #########8 |  99%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #####3     |  53%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 3          |   4%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #####9     |  59%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 4          |   4%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ######5    |  65%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 4          |   5%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #######3   |  73%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 5          |   5%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 5          |   6%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 6          |   6%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | #########7 |  97%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 6          |   7%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 7          |   8%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 8          |   8%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | 9          |  10%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #          |  11%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #1         |  12%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #2         |  13%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #3         |  14%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #4         |  15%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #5         |  16%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #6         |  17%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #7         |  18%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #8         |  19%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #9         |  20%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##         |  21%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##1        |  22%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##2        |  22%
#
#
# matplotlib-base-3.7. | 6.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##3        |  23%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##4        |  24%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##4        |  25%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##5        |  26%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##6        |  27%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##7        |  28%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##8        |  28%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ##9        |  29%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###        |  30%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###1       |  31%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###2       |  32%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###3       |  33%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###3       |  34%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###4       |  35%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###5       |  36%
#
#
#
# numpy-base-1.26.0    | 6.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###6       |  37%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###7       |  37%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###8       |  38%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ###9       |  39%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####       |  40%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####       |  41%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####1      |  42%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####2      |  43%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####3      |  44%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####4      |  44%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####5      |  45%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####6      |  46%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####7      |  47%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####7      |  48%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####8      |  49%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ####9      |  50%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####      |  51%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####1     |  52%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####2     |  53%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####3     |  53%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####4     |  54%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####5     |  55%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####6     |  56%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####7     |  57%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####8     |  58%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####8     |  59%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #####9     |  60%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######     |  61%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######1    |  61%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######2    |  62%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######2    |  63%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######3    |  64%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######4    |  64%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######5    |  65%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######5    |  66%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######6    |  67%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######7    |  67%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######8    |  68%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######9    |  69%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ######9    |  70%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######    |  71%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######1   |  71%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######1   |  72%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######2   |  73%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######3   |  73%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######3   |  74%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######4   |  75%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######5   |  75%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######5   |  76%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######6   |  77%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######7   |  77%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######7   |  78%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######8   |  79%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #######9   |  79%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########   |  80%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########   |  81%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########1  |  81%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########1  |  82%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########2  |  83%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########3  |  83%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########4  |  84%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########5  |  85%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########6  |  86%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########7  |  87%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########8  |  88%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########8  |  89%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########9  |  90%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########  |  91%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########1 |  91%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########2 |  92%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########2 |  93%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########3 |  94%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########4 |  95%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########5 |  96%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########6 |  97%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########7 |  98%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########8 |  98%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | #########9 |  99%
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 155.6 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\shlbs\OneDrive - The University of Texas at Austin\Desktop\Cornudas_Processed_FieldSpec\CND001\CND001_Processed.csv', header = None)

# %%
df.head()
# Out:
#                  0  1    2      3
# 0  CND00100000.asd  1  350  0.565
# 1  CND00100000.asd  2  351  0.565
# 2  CND00100000.asd  3  352  0.561
# 3  CND00100000.asd  4  353  0.562
# 4  CND00100000.asd  5  354  0.565

# %%
unique_values = df.iloc[:, 0].unique()

# %%
fig, ax = plt.subplots()
for value in unique_values:
    subset = df[df.iloc[:, 0] == value]
    ax.scatter(subset.iloc[:, 2], subset.iloc[:, 3], label=str(value))

# Add labels and title
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Absolute Reflectance')
ax.set_title('CND001 Field Spec Data')

# Add legend
ax.legend()

# Show the plot
plt.show()

# %%
# Create a colormap with desired colors
num_colors = len(unique_values)
cmap = plt.cm.get_cmap('viridis', num_colors)  


fig, ax = plt.subplots(figsize=(24, 12))
for idx, value in enumerate(unique_values):
    subset = df[df.iloc[:, 0] == value]
    color = cmap(idx)  # Get color from the colormap
    ax.plot(subset.iloc[:, 2], subset.iloc[:, 3],'-', label=str(value), color=color)

# Add labels and title
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Absolute Reflectance')
ax.set_title('CND001 Field Spec Data')

# Add legend with custom colors
handles, labels = ax.get_legend_handles_labels()
custom_legend = [(handle, label) for handle, label in zip(handles, labels)]
ax.legend(*zip(*custom_legend), loc='upper left')

# Show the plot
plt.show()
# Out:
# C:\Users\shlbs\AppData\Local\Temp\ipykernel_25224\3374693181.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis', num_colors)

# %% [markdown]
# ## Mean
# The .mean() function in pandas calculates the arithmetic mean, which is the most common type of mean. The arithmetic mean is computed by summing up all the values in a dataset and then dividing by the total number of values.
#
# Mathematically, the arithmetic mean (μ) is calculated as:
#
# μ = (x₁ + x₂ + x₃ + ... + xₙ) / n
#
# Where:
#
# x₁, x₂, ..., xₙ are the individual values in the dataset.
# n is the total number of values in the dataset.
#
# '.groupby(2)': This groups the data in your DataFrame based on the values in column index 2 (presumably the wavelength column). This creates groups where data points with the same wavelength are grouped together.
#
# [3]: This selects the column at index 3 (presumably the reflectance column) from each group.
#
# .mean(): This calculates the mean value of the selected column within each group. So, for each unique wavelength, you're calculating the average reflectance value across all data points with that wavelength.

# %%
fig_avg, ax_avg = plt.subplots(figsize=(24, 12))  # Adjust width and height as needed

# Calculate the average signature
average_signature = df.groupby(2)[3].mean()  # Assuming column 2 is the wavelength and column 3 is the reflectance

# Plot the average signature
ax_avg.plot(average_signature.index, average_signature.values, 'r-', label='Average Signature') 

# Add labels and title
ax_avg.set_xlabel('Wavelength (nm)')
ax_avg.set_ylabel('Average Reflectance')
ax_avg.set_title('Average Reflectance Signature')

# Add legend
ax_avg.legend()

# Show both plots
plt.show()

# %%
fig, ax = plt.subplots(figsize=(24, 12))
for idx, value in enumerate(unique_values):
    subset = df[df.iloc[:, 0] == value]
    color = cmap(idx)  # Get color from the colormap
    ax.plot(subset.iloc[:, 2], subset.iloc[:, 3],'-', label=str(value), color=color)
ax.plot(average_signature.index, average_signature.values, 'r-', label='Average Signature') 

# Add labels and title
ax.set_xlabel('Wavelength (nm)')
ax.set_ylabel('Absolute Reflectance')
ax.set_title('CND001 Field Spec Data')

# Add legend with custom colors
handles, labels = ax.get_legend_handles_labels()
custom_legend = [(handle, label) for handle, label in zip(handles, labels)]
ax.legend(*zip(*custom_legend), loc='upper left')

# Show the plot
plt.show()

# %%
average_signature = df.groupby(2)[3].mean().reset_index()  # Reset index to convert groupby result to DataFrame

# Rename columns for clarity
average_signature.columns = ['Wavelength (nm)', 'Average Reflectance']

# Export the average signature to a CSV file
average_signature.to_csv(r'C:\Users\shlbs\OneDrive - The University of Texas at Austin\Desktop\Cornudas_Processed_FieldSpec\CND001\CND001_Average.csv', index=False)
