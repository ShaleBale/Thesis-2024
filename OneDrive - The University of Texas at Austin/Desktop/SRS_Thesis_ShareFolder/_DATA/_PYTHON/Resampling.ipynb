# %%
# !pip install spectral
# Out:
# Requirement already satisfied: spectral in c:\users\shlbs\miniconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: numpy in c:\users\shlbs\miniconda3\lib\site-packages (from spectral) (1.26.0)

# %%
import numpy as np
from scipy.interpolate import interp1d
import spectral as spy

# %%
import matplotlib.pyplot as plt

# %%
hdr_file_path = r'D:\Shelby_GDrive\THESIS\ENVI\Sen_LayerStack_10m.hdr'

# %%
Sen_LayerStack_10m = spy.envi.open(hdr_file_path)

# %%
spy.imshow(Sen_LayerStack_10m)

# Add a color bar for reference
plt.colorbar(label='Reflectance')

# Add title and axis labels
plt.title('Hyperspectral Image')
plt.xlabel('Column')
plt.ylabel('Row')

# Show the plot
plt.show()
# Out:
# C:\Users\shlbs\miniconda3\lib\site-packages\spectral\graphics\spypylab.py:796: UserWarning: Failed to create RectangleSelector object. Interactive pixel class labeling will be unavailable.
#   warnings.warn(msg)
